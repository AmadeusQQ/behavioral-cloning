# %% [markdown]
# # Import dependencies

# %%
from os import listdir
from os.path import join
from cv2 import COLOR_BGR2RGB, cvtColor, imread
import numpy as np
from matplotlib import pyplot

# %% [markdown]
# # Set parameters

# %%
path = './data/IMG'
sample_image = 'center_2016_12_01_13_37_16_570.jpg'

# %% [markdown]
# # Get data
#
# Use data by Udacity.
#
# Source: https://d17h27t6h515a5.cloudfront.net/topher/2016/December/584f6edd_data/data.zip
#
# Size: 322.8 MB

# %%
# Do not execute this cell as it will read all images into memory
stop

data = np.array([imread(join(path, file)) for file in listdir(path)], dtype = 'float32')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e61697e2b5cf> in <module>()
#       1 # Do not execute this cell as it will read all images into memory
# ----> 2 stop
#       3
#       4 data = np.array([imread(join(path, file)) for file in listdir(path)], dtype = 'float32')
#
# NameError: name 'stop' is not defined

# %% [markdown]
# # Explore data

# %%
print('Count:', len(listdir(path)))
# Out:
# Count: 24108

# %%
image = imread(join(path, sample_image))
print('Shape:', image.shape)
# Out:
# Shape: (160, 320, 3)

# %%
image = cvtColor(image, COLOR_BGR2RGB)
pyplot.imshow(image)
pyplot.show()
